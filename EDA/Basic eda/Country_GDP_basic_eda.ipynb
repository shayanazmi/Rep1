# %%
#Install required packages
# !pip install pandas numpy
# !pip install lxml

import numpy as np
import pandas as pd

# %%
# Extract tables from the webpage
tables = pd.read_html("https://web.archive.org/web/20230902185326/https://en.wikipedia.org/wiki/List_of_countries_by_GDP_%28nominal%29")

# Retain table number 3 as the required DataFrame
df = tables[3]

# Replace the column headers with column numbers
df.columns = range(df.shape[1])

# Print the columns to check
print(df.columns)
# Out:
# RangeIndex(start=0, stop=8, step=1)

# %%
# Retain columns with index 0 and 2 (name of country and value of GDP quoted by IMF)
df = df.iloc[:, [0,1]]
print(df)
# Out:
#           Country  GDP(Million USD)
# 0            World        105568776
# 1    United States         26854599
# 2            China         19373586
# 3            Japan          4409738
# 4          Germany          4308854
# 5            India          3736882
# 6   United Kingdom          3158938
# 7           France          2923489
# 8            Italy          2169745
# 9           Canada          2089672
# 10          Brazil          2081235
#           Country  GDP(Million USD)
# 0            World        105568776
# 1    United States         26854599
# 2            China         19373586
# 3            Japan          4409738
# 4          Germany          4308854
# 5            India          3736882
# 6   United Kingdom          3158938
# 7           France          2923489
# 8            Italy          2169745
# 9           Canada          2089672
# 10          Brazil          2081235

# %%
# Retain the rows with index 0 to 9, indicating the top 10 economies of the world
df = df.iloc[0:11, : ]
print(df)
# Out:
#           Country  GDP(Million USD)
# 0            World        105568776
# 1    United States         26854599
# 2            China         19373586
# 3            Japan          4409738
# 4          Germany          4308854
# 5            India          3736882
# 6   United Kingdom          3158938
# 7           France          2923489
# 8            Italy          2169745
# 9           Canada          2089672
# 10          Brazil          2081235

# %%
# Assign column names as "Country" and "GDP (Million USD)"
df.columns = [ "Country " , "GDP(Million USD)"]

# Display the DataFrame to ensure the correct data is retained
print(df)
# Out:
#           Country  GDP(Million USD)
# 0            World        105568776
# 1    United States         26854599
# 2            China         19373586
# 3            Japan          4409738
# 4          Germany          4308854
# 5            India          3736882
# 6   United Kingdom          3158938
# 7           France          2923489
# 8            Italy          2169745
# 9           Canada          2089672
# 10          Brazil          2081235

# %%
# Change the data type of the 'GDP (Million USD)' column to integer. Use astype() method.
df['GDP(Million USD)'] = df['GDP(Million USD)'].astype(int)

# %%
# Convert the GDP value in Million USD to Billion USD
df[['GDP(Million USD)']] = df[['GDP(Million USD)']]/1000
print(df['GDP(Million USD)'])
# Out:
# 0     105.56878
# 1      26.85460
# 2      19.37359
# 3       4.40974
# 4       4.30885
# 5       3.73688
# 6       3.15894
# 7       2.92349
# 8       2.16974
# 9       2.08967
# 10      2.08124
# Name: GDP(Million USD), dtype: float64

# %%
# Use numpy.round() method to round the value to 2 decimal places.
df[['GDP(Million USD)']] = np.round(df[['GDP(Million USD)']], 2)
print(df[['GDP(Million USD)']])
# Out:
#     GDP(Million USD)
# 0          105568.78
# 1           26854.60
# 2           19373.59
# 3            4409.74
# 4            4308.85
# 5            3736.88
# 6            3158.94
# 7            2923.49
# 8            2169.74
# 9            2089.67
# 10           2081.24
#           Country   GDP(Million USD)
# 0            World         105568.78
# 1    United States          26854.60
# 2            China          19373.59
# 3            Japan           4409.74
# 4          Germany           4308.85
# 5            India           3736.88
# 6   United Kingdom           3158.94
# 7           France           2923.49
# 8            Italy           2169.74
# 9           Canada           2089.67
# 10          Brazil           2081.24

# %%
# Rename the column header from 'GDP (Million USD)' to 'GDP (Billion USD)'
df.rename(columns = {'GDP(Million USD)' : 'GDP(Billion USD)'})
# Out:
#           Country   GDP(Billion USD)
# 0            World         105.56878
# 1    United States          26.85460
# 2            China          19.37359
# 3            Japan           4.40974
# 4          Germany           4.30885
# 5            India           3.73688
# 6   United Kingdom           3.15894
# 7           France           2.92349
# 8            Italy           2.16974
# 9           Canada           2.08967
# 10          Brazil           2.08124

# %%
df.to_csv('GDP.csv')

# %%
pd.read_csv('GDP.csv')
df.head()
# Out:
#         Country   GDP(Million USD)
# 0          World               105
# 1  United States                26
# 2          China                19
# 3          Japan                 4
# 4        Germany                 4
